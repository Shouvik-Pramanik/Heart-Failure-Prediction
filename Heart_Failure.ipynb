# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import keras
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score,f1_score

data = pd.read_csv('heart_failure.csv')
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
cols= ["green","red"]
sns.countplot(x= data["DEATH_EVENT"], palette= cols)
# Out:
# <AxesSubplot:xlabel='DEATH_EVENT', ylabel='count'>

# %%
X=data.drop(["DEATH_EVENT"],axis=1)
y=data["DEATH_EVENT"]

# %%
col_names = list(X.columns)
s_scaler = StandardScaler()
X_df= s_scaler.fit_transform(X)
X_df = pd.DataFrame(X_df, columns=col_names)   
X_df.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.265205e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  3.594301e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  3.713120e-18  1.001676 -0.576918 -0.480393
# diabetes                  299.0  1.113936e-16  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0  3.341808e-18  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0 -4.841909e-16  1.001676 -0.735688 -0.735688
# platelets                 299.0  1.009969e-16  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0 -2.227872e-18  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.627435e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -5.940993e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -3.861645e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.069379e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
X_train, X_test, y_train,y_test = train_test_split(X_df,y,test_size=0.3,random_state=2)

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001,
    patience=30, 
    restore_best_weights=True)

model = Sequential()
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
from tensorflow.keras.optimizers import SGD
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, batch_size = 32, epochs = 500,callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 39ms/step - loss: 0.6929 - accuracy: 0.6407 - val_loss: 0.6923 - val_accuracy: 0.6429
# Epoch 2/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6919 - accuracy: 0.6587 - val_loss: 0.6915 - val_accuracy: 0.6429
# Epoch 3/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6910 - accuracy: 0.6587 - val_loss: 0.6906 - val_accuracy: 0.6429
# Epoch 4/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6901 - accuracy: 0.6587 - val_loss: 0.6898 - val_accuracy: 0.6429
# Epoch 5/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6890 - accuracy: 0.6587 - val_loss: 0.6889 - val_accuracy: 0.6429
# Epoch 6/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6881 - accuracy: 0.6587 - val_loss: 0.6880 - val_accuracy: 0.6429
# Epoch 7/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6870 - accuracy: 0.6587 - val_loss: 0.6870 - val_accuracy: 0.6429
# Epoch 8/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6857 - accuracy: 0.6587 - val_loss: 0.6858 - val_accuracy: 0.6429
# Epoch 9/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6842 - accuracy: 0.6587 - val_loss: 0.6844 - val_accuracy: 0.6429
# Epoch 10/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6824 - accuracy: 0.6587 - val_loss: 0.6826 - val_accuracy: 0.6429
# Epoch 11/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6792 - accuracy: 0.6587 - val_loss: 0.6804 - val_accuracy: 0.6429
# Epoch 12/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6783 - accuracy: 0.6587 - val_loss: 0.6776 - val_accuracy: 0.6429
# Epoch 13/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6754 - accuracy: 0.6587 - val_loss: 0.6742 - val_accuracy: 0.6429
# Epoch 14/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6713 - accuracy: 0.6587 - val_loss: 0.6695 - val_accuracy: 0.6429
# Epoch 15/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6667 - accuracy: 0.6587 - val_loss: 0.6636 - val_accuracy: 0.6429
# Epoch 16/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6567 - accuracy: 0.6587 - val_loss: 0.6557 - val_accuracy: 0.6429
# Epoch 17/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6468 - accuracy: 0.6587 - val_loss: 0.6459 - val_accuracy: 0.6429
# Epoch 18/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6381 - accuracy: 0.6587 - val_loss: 0.6336 - val_accuracy: 0.6429
# Epoch 19/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6235 - accuracy: 0.6587 - val_loss: 0.6197 - val_accuracy: 0.6429
# Epoch 20/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6121 - accuracy: 0.6587 - val_loss: 0.6050 - val_accuracy: 0.6429
# Epoch 21/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6010 - accuracy: 0.6587 - val_loss: 0.5922 - val_accuracy: 0.6429
# Epoch 22/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5787 - accuracy: 0.6587 - val_loss: 0.5785 - val_accuracy: 0.6429
# Epoch 23/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5590 - accuracy: 0.6587 - val_loss: 0.5634 - val_accuracy: 0.6429
# Epoch 24/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5399 - accuracy: 0.6587 - val_loss: 0.5492 - val_accuracy: 0.6429
# Epoch 25/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5372 - accuracy: 0.6587 - val_loss: 0.5384 - val_accuracy: 0.6429
# Epoch 26/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5486 - accuracy: 0.6587 - val_loss: 0.5294 - val_accuracy: 0.6429
# Epoch 27/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5200 - accuracy: 0.6587 - val_loss: 0.5213 - val_accuracy: 0.6429
# Epoch 28/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5592 - accuracy: 0.6587 - val_loss: 0.5168 - val_accuracy: 0.6429
# Epoch 29/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5302 - accuracy: 0.6587 - val_loss: 0.5134 - val_accuracy: 0.6429
# Epoch 30/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5125 - accuracy: 0.6587 - val_loss: 0.5110 - val_accuracy: 0.6429
# Epoch 31/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4986 - accuracy: 0.6587 - val_loss: 0.5093 - val_accuracy: 0.6429
# Epoch 32/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4963 - accuracy: 0.6587 - val_loss: 0.5084 - val_accuracy: 0.6429
# Epoch 33/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5062 - accuracy: 0.6587 - val_loss: 0.5078 - val_accuracy: 0.6429
# Epoch 34/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4703 - accuracy: 0.6587 - val_loss: 0.5073 - val_accuracy: 0.6429
# Epoch 35/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4901 - accuracy: 0.6587 - val_loss: 0.5069 - val_accuracy: 0.6429
# Epoch 36/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4812 - accuracy: 0.6587 - val_loss: 0.5063 - val_accuracy: 0.6429
# Epoch 37/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4700 - accuracy: 0.6587 - val_loss: 0.5069 - val_accuracy: 0.6429
# Epoch 38/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4995 - accuracy: 0.6587 - val_loss: 0.5072 - val_accuracy: 0.6429
# Epoch 39/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4637 - accuracy: 0.6587 - val_loss: 0.5076 - val_accuracy: 0.6429
# Epoch 40/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4598 - accuracy: 0.6587 - val_loss: 0.5063 - val_accuracy: 0.6429
# Epoch 41/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4683 - accuracy: 0.6587 - val_loss: 0.5029 - val_accuracy: 0.6429
# Epoch 42/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4957 - accuracy: 0.6587 - val_loss: 0.5000 - val_accuracy: 0.6429
# Epoch 43/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4943 - accuracy: 0.6587 - val_loss: 0.4973 - val_accuracy: 0.6429
# Epoch 44/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4918 - accuracy: 0.6587 - val_loss: 0.4980 - val_accuracy: 0.6429
# Epoch 45/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4578 - accuracy: 0.6587 - val_loss: 0.5002 - val_accuracy: 0.6429
# Epoch 46/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4793 - accuracy: 0.6587 - val_loss: 0.5013 - val_accuracy: 0.6429
# Epoch 47/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4920 - accuracy: 0.6587 - val_loss: 0.5020 - val_accuracy: 0.6429
# Epoch 48/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4860 - accuracy: 0.6587 - val_loss: 0.5022 - val_accuracy: 0.6429
# Epoch 49/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4512 - accuracy: 0.6587 - val_loss: 0.5011 - val_accuracy: 0.6429
# Epoch 50/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4498 - accuracy: 0.6587 - val_loss: 0.5012 - val_accuracy: 0.6429
# Epoch 51/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4626 - accuracy: 0.6587 - val_loss: 0.5001 - val_accuracy: 0.6429
# Epoch 52/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4886 - accuracy: 0.6587 - val_loss: 0.4992 - val_accuracy: 0.6429
# Epoch 53/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4516 - accuracy: 0.6587 - val_loss: 0.4990 - val_accuracy: 0.6429
# Epoch 54/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4513 - accuracy: 0.6587 - val_loss: 0.5019 - val_accuracy: 0.6429
# Epoch 55/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4424 - accuracy: 0.6587 - val_loss: 0.5063 - val_accuracy: 0.6429
# Epoch 56/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4556 - accuracy: 0.6587 - val_loss: 0.5087 - val_accuracy: 0.6429
# Epoch 57/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4621 - accuracy: 0.6587 - val_loss: 0.5080 - val_accuracy: 0.6429
# Epoch 58/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5123 - accuracy: 0.6587 - val_loss: 0.5097 - val_accuracy: 0.6429
# Epoch 59/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4641 - accuracy: 0.6587 - val_loss: 0.5109 - val_accuracy: 0.6429
# Epoch 60/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4673 - accuracy: 0.6587 - val_loss: 0.5090 - val_accuracy: 0.6429
# Epoch 61/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4466 - accuracy: 0.6587 - val_loss: 0.5109 - val_accuracy: 0.6429
# Epoch 62/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4835 - accuracy: 0.6587 - val_loss: 0.5111 - val_accuracy: 0.6429
# Epoch 63/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4701 - accuracy: 0.6587 - val_loss: 0.5108 - val_accuracy: 0.6429
# Epoch 64/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4507 - accuracy: 0.6587 - val_loss: 0.5103 - val_accuracy: 0.7381
# Epoch 65/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4245 - accuracy: 0.8263 - val_loss: 0.5107 - val_accuracy: 0.7381
# Epoch 66/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4662 - accuracy: 0.8263 - val_loss: 0.5091 - val_accuracy: 0.7381
# Epoch 67/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4696 - accuracy: 0.7725 - val_loss: 0.5040 - val_accuracy: 0.7381
# Epoch 68/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4487 - accuracy: 0.8503 - val_loss: 0.5031 - val_accuracy: 0.7381
# Epoch 69/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4259 - accuracy: 0.8204 - val_loss: 0.5035 - val_accuracy: 0.7381
# Epoch 70/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4340 - accuracy: 0.8144 - val_loss: 0.5032 - val_accuracy: 0.7381
# Epoch 71/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5020 - accuracy: 0.7725 - val_loss: 0.5048 - val_accuracy: 0.7381
# Epoch 72/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4198 - accuracy: 0.8443 - val_loss: 0.5065 - val_accuracy: 0.7381
# Epoch 73/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4435 - accuracy: 0.8024 - val_loss: 0.5095 - val_accuracy: 0.7381

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 65.59%

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
y_test
# Out:
# 179    0
# 221    0
# 226    0
# 7      1
# 173    0
#       ..
# 155    0
# 71     0
# 277    0
# 219    0
# 128    0
# Name: DEATH_EVENT, Length: 90, dtype: int64

# %%
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <AxesSubplot:>
